# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import cv2
import numpy as np
from PIL import Image
from tqdm import tqdm

def Create_Directory_DataFrame():
    df_list = []  
    basedir = 'A. Segmentation/1. Original Images/'
    
    for Class in os.listdir(basedir):
        class_dir = os.path.join(basedir, Class)
        if os.path.isdir(class_dir): 
            for location in os.listdir(class_dir):
                if location.endswith('.jpg'):
                    
                    class_name = Class.split('.')[1].strip() if '.' in Class else Class
                    image_id = location.split('.')[0].split('_')[1]
                    df_list.append({
                        'Class': class_name,
                        'Location': os.path.join(class_dir, location),
                        'ID': image_id
                    })
    

    df = pd.DataFrame(df_list)
    df = df.sample(frac=1).reset_index(drop=True)  
    return df

df1 = Create_Directory_DataFrame()
print(df1.shape)
df1.head()
# Out:
# (81, 3)
#           Class                                           Location  ID
# 0  Training Set  A. Segmentation/1. Original Images/a. Training...  47
# 1  Training Set  A. Segmentation/1. Original Images/a. Training...  17
# 2   Testing Set  A. Segmentation/1. Original Images/b. Testing ...  78
# 3   Testing Set  A. Segmentation/1. Original Images/b. Testing ...  61
# 4  Training Set  A. Segmentation/1. Original Images/a. Training...  36

# %%
import pandas as pd
import os

def Create_Directory_DataFrame():
    records = [] 
    basedir = '/Users/sheebamoghal/Desktop/DSAN-6600/project-1/A. Segmentation/2. All Segmentation Groundtruths'

    for Class in os.listdir(basedir):
        class_path = os.path.join(basedir, Class)
        if os.path.isdir(class_path):  
            for SubClass in os.listdir(class_path):
                subclass_path = os.path.join(class_path, SubClass)
                if os.path.isdir(subclass_path):  
                    for filename in os.listdir(subclass_path):
                        if filename.endswith('.tif'):
                            record = {
                                'Class': Class,
                                'SubClass': SubClass,
                                'Location': os.path.join(subclass_path, filename),
                                'ID': filename.split('.')[0].split('_')[1]
                            }
                            records.append(record)

    df = pd.DataFrame.from_records(records) 
    df = df.sample(frac=1).reset_index(drop=True)  
    return df

df = Create_Directory_DataFrame()
print(df.shape)
df.head()
# Out:
# (363, 4)
#              Class           SubClass  \
# 0  a. Training Set    2. Haemorrhages
# 1   b. Testing Set   3. Hard Exudates
# 2  a. Training Set  1. Microaneurysms
# 3  a. Training Set   3. Hard Exudates
# 4   b. Testing Set      5. Optic Disc
#
#                                             Location  ID
# 0  /Users/sheebamoghal/Desktop/DSAN-6600/project-...  50
# 1  /Users/sheebamoghal/Desktop/DSAN-6600/project-...  60
# 2  /Users/sheebamoghal/Desktop/DSAN-6600/project-...  10
# 3  /Users/sheebamoghal/Desktop/DSAN-6600/project-...  30
# 4  /Users/sheebamoghal/Desktop/DSAN-6600/project-...  59

# %%
df.groupby(['SubClass']).count()
# Out:
#                    Class  Location  ID
# SubClass
# 1. Microaneurysms     81        81  81
# 2. Haemorrhages       80        80  80
# 3. Hard Exudates      81        81  81
# 4. Soft Exudates      40        40  40
# 5. Optic Disc         81        81  81

# %%
fdf = pd.merge(df, df1, left_on='ID', right_on='ID')
fdf.head()
# Out:
#            Class_x           SubClass  \
# 0  a. Training Set    2. Haemorrhages
# 1  a. Training Set   3. Hard Exudates
# 2  a. Training Set   4. Soft Exudates
# 3  a. Training Set  1. Microaneurysms
# 4  a. Training Set      5. Optic Disc
#
#                                           Location_x  ID       Class_y  \
# 0  /Users/sheebamoghal/Desktop/DSAN-6600/project-...  50  Training Set
# 1  /Users/sheebamoghal/Desktop/DSAN-6600/project-...  50  Training Set
# 2  /Users/sheebamoghal/Desktop/DSAN-6600/project-...  50  Training Set
# 3  /Users/sheebamoghal/Desktop/DSAN-6600/project-...  50  Training Set
# 4  /Users/sheebamoghal/Desktop/DSAN-6600/project-...  50  Training Set
#
#                                           Location_y
# 0  A. Segmentation/1. Original Images/a. Training...
# 1  A. Segmentation/1. Original Images/a. Training...
# 2  A. Segmentation/1. Original Images/a. Training...
# 3  A. Segmentation/1. Original Images/a. Training...
# 4  A. Segmentation/1. Original Images/a. Training...

# %%
print(fdf['SubClass'].unique())
# Out:
# ['2. Haemorrhages' '3. Hard Exudates' '4. Soft Exudates'
#  '1. Microaneurysms' '5. Optic Disc']

# %%
w,h = 2848,4288
#w,h=512,512
from tqdm import tqdm
def load_img(addr,w,h):
    img = cv2.imread(addr,0)
    img = cv2.resize(img, (w,h), interpolation = cv2.INTER_AREA)
    img = img.reshape(w,h,1)
    return img
def load_mask(addr, w, h):
    im = Image.open(addr)
    imarray = np.array(im)
    img = cv2.resize(imarray, (w, h), interpolation=cv2.INTER_AREA)
    img = img.reshape(w, h, 3) 

def load_data(df,w,h):
    Image = []
    Masks = []
    for i in tqdm(df.index):
        Image.append(load_img(df.loc[i]['Location_x'],w,h))
        Masks.append(load_mask(df.loc[i]['Location_y'],w,h))
    return np.float32(np.array(Image)) , np.float32(np.array(Masks))

segment_choice = '2. Haemorrhages'
seg_df = fdf[fdf['SubClass'] ==  segment_choice]
print(seg_df.shape)
seg_df.head()
# Out:
# (80, 6)
#             Class_x         SubClass  \
# 0   a. Training Set  2. Haemorrhages
# 9    b. Testing Set  2. Haemorrhages
# 13  a. Training Set  2. Haemorrhages
# 18  a. Training Set  2. Haemorrhages
# 23   b. Testing Set  2. Haemorrhages
#
#                                            Location_x  ID       Class_y  \
# 0   /Users/sheebamoghal/Desktop/DSAN-6600/project-...  50  Training Set
# 9   /Users/sheebamoghal/Desktop/DSAN-6600/project-...  60   Testing Set
# 13  /Users/sheebamoghal/Desktop/DSAN-6600/project-...  10  Training Set
# 18  /Users/sheebamoghal/Desktop/DSAN-6600/project-...  30  Training Set
# 23  /Users/sheebamoghal/Desktop/DSAN-6600/project-...  59   Testing Set
#
#                                            Location_y
# 0   A. Segmentation/1. Original Images/a. Training...
# 9   A. Segmentation/1. Original Images/b. Testing ...
# 13  A. Segmentation/1. Original Images/a. Training...
# 18  A. Segmentation/1. Original Images/a. Training...
# 23  A. Segmentation/1. Original Images/b. Testing ...

# %%
from PIL import Image
im = Image.open(fdf.iloc[21,5])
imarray = np.array(im)
plt.imshow(imarray)
print(imarray.shape)
# Out:
# (2848, 4288, 3)

# %%
from PIL import Image
im = Image.open(fdf.iloc[1,5])
imarray = np.array(im)
plt.imshow(imarray)
print(imarray.shape)
# Out:
# (2848, 4288, 3)

# %%
X, Y = load_data(seg_df,w,h)
# Out:
# 100%|██████████| 80/80 [00:07<00:00, 10.41it/s]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, random_state=42)
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.15, random_state=42)

# %%
from transformers import ViTForImageClassification, ViTFeatureExtractor
import torch

feature_extractor = ViTFeatureExtractor.from_pretrained('google/vit-base-patch16-224-in21k')
model = ViTForImageClassification.from_pretrained('google/vit-base-patch16-224-in21k')


num_classes = 2  # number of target classes
model.classifier = torch.nn.Linear(model.classifier.in_features, num_classes)
